# %%
print("Hello world ");
# Out:
# Hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# python Second program

# %%
print("*"*3)
# Out:
# ***

# %%
print("*\n"*3)
# Out:
# *
# *
# *

# %%
print("*" * 3 ,sep="\n")
# Out:
# ***

# %%
Name="Harsh"
print(Name)
# Out:
# Harsh
